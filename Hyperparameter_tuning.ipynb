# %%
# !pip install -q -U keras-tuner

# %%
# importing the library
from tensorflow.keras.callbacks import EarlyStopping
import keras_tuner as kt
from tensorflow import keras
import kagglehub
from fastai import *
import tensorflow as tf
import cv2
import os
import random
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
# Download latest version
path = kagglehub.dataset_download("rajumavinmar/finger-print-based-blood-group-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/finger-print-based-blood-group-dataset

# %%
dataset_path = os.path.join(path, "dataset_blood_group")

# %%
#Type of Blood Group
blood_group=['A+', 'A-', 'AB+', 'AB-', 'B+', 'B-', 'O+', 'O-']

# %%
for blood in blood_group:
  fig, _ =plt.subplots(3, 3)
  fig.suptitle(blood)
  for k, n in enumerate(os.listdir(dataset_path+'/'+blood)[:9]):
    img=plt.imread(dataset_path+'/'+blood+'/'+n)
    plt.subplot(3,3,k+1)
    plt.axis('off')
    plt.imshow(img)
  plt.show()

# %%
feat=[]
names=[]
image_path=[]
height=128
width=128
n_channels=3

# %%
for k, blood in enumerate(blood_group):
  for f in os.listdir(dataset_path+'/'+blood):
    image_path.append([dataset_path+'/'+blood+'/'+f, k])

print(image_path)
# Out:
# [['/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/A+/cluster_0_1554.BMP', 0], ['/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/A+/cluster_0_994.BMP', 0], ['/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/A+/cluster_0_4617.BMP', 0], ['/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/A+/cluster_0_3270.BMP', 0], ['/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/A+/cluster_0_5366.BMP', 0], ['/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/A+/cluster_0_3134.BMP', 0], ['/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/A+/cluster_0_4840.BMP', 0], ['/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/A+/cluster_0_5286.BMP', 0], ['/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/A+/cluster_0_4399.BMP', 0], ['/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/A+/cluster_0_3822.BMP', 0], ['/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/A+/cluster_0_400.BMP', 0], ['/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/A+/cluster_0_3334.BMP', 0], ['/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/A+/cluster_0_2434.BMP', 0], ['/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/A+/cluster_0_1843.BMP', 0], ['/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/A+/cluster_0_4038.BMP', 0], ['/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/A+/cluster_0_2959.BMP', 0], ['/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/A+/cluster_0_4079.BMP', 0], ['/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/A+/cluster_0_1196.BMP', 0], ['/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/A+/cluster_0_2640.BMP', 0], ['/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/A+/cluster_0_5813.BMP', 0], ['/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/A+/cluster_0_576.BMP', 0], ['/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/A+/cluster_0_4949.BMP', 0], ['/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/A+/cluster_0_1389.BMP', 0], ['/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/A+/cluster_0_707.BMP', 0], ['/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/A+/cluster_0_2268.BMP', 0], ['/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/A+/cluster_0_2452.BMP', 0], ['/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/A+/cluster_0_3410.BMP', 0], ['/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/A+/cluster_0_3291.BMP', 0], ['/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/A+/cluster_0_4700.BMP', 0], ['/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/A+/cluster_0_5734.BMP', 0], ['/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/A+/cluster_0_3339.BMP', 0], ['/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/A+/cluster_0_3179.BMP', 0], ['/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/A+/cluster_0_4905.BMP', 0], ['/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/A+/cluster_0_1217.BMP', 0], ['/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/A+/cluster_0_3873.BMP', 0], ['/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/A+/cluster_0_2603.BMP', 0], ['/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/A+/cluster_0_3089.BMP', 0], ['/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/A+/cluster_0_5687.BMP', 0], ['/kaggle/input/finger-print-based-blood-group-dataset/dataset_blood_group/A+/cluster_0_1 ...

# %%
for imagepath in image_path:
  image=cv2.imread(imagepath[0])
  image=cv2.resize(image, (width, height))
  feat.append(image)

  name=imagepath[1]
  names.append(name)

# %%
feat=np.array(feat, dtype='float') / 255.0
names=np.array(names)

# %%
(x_train, x_test, y_train, y_test)=train_test_split(feat, names, test_size=0.2, random_state=13, stratify=names)

# %%
def model_builder(hp):
  # Choicing the right activation function with the help of tuner(hyperparameter finding library)
  activation1=hp.Choice("activation1",['relu','sigmoid','softmax'])
  # Finding the right learning rate
  hp_learning_rate=hp.Float('learning_rate', min_value=1e-5, max_value=1e-2, sampling='log')
  # Finding the Dropout
  dropout_rate=hp.Float('dropout', 0, 0.5, step=0.1)
  # Finding the neurons number
  hp_units=hp.Int('units', min_value=32, max_value=128, step=32)
  #creating the model
  model=keras.Sequential()
  model.add(keras.layers.InputLayer((128, 128, 3)))
  model.add(keras.layers.Conv2D(filters=hp_units, kernel_size=(3,3), activation=activation1))
  model.add(keras.layers.MaxPool2D())
  model.add(keras.layers.Conv2D(filters=hp_units, kernel_size=(3,3), activation=activation1))
  model.add(keras.layers.MaxPool2D())
  model.add(keras.layers.Flatten())
  model.add(keras.layers.Dense(units=hp_units, activation=activation1))
  model.add(keras.layers.Dense(8, activation="softmax"))


  #model compiling
  model.compile(optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
                loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                metrics=['accuracy'])
  return model

# %%
tuner=kt.Hyperband(model_builder,
                   objective='val_accuracy',
                   max_epochs=10,
                   factor=3,
                   directory='my_dir',
                   project_name="Hyper")

# %%
stop_early=tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %%
tuner.search(x_train,y=y_train,epochs=50, validation_split=0.2,callbacks=[stop_early])
# Out:
# Trial 30 Complete [00h 00m 47s]
# val_accuracy: 0.17395833134651184
#
# Best val_accuracy So Far: 0.9125000238418579
# Total elapsed time: 00h 17m 09s

# %%
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]
print(f"""
The hyperparameter search is complete. The optimal number of units in the first densely-connected
layer is {best_hps.get('units')} and the optimal learning rate for the optimizer
is {best_hps.get('learning_rate')}.
""")
# Out:
# The hyperparameter search is complete. The optimal number of units in the first densely-connected
# layer is 96 and the optimal learning rate for the optimizer
# is 0.00017879831499230929.

# %%
# Build the model with the optimal hyperparameters and train it on the data for 50 epochs
model = tuner.hypermodel.build(best_hps)
history = model.fit(x_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 8s 50ms/step - accuracy: 0.3674 - loss: 1.7049 - val_accuracy: 0.7906 - val_loss: 0.6258
# Epoch 2/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - accuracy: 0.8127 - loss: 0.5353 - val_accuracy: 0.8302 - val_loss: 0.4572
# Epoch 3/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.8714 - loss: 0.3445 - val_accuracy: 0.8729 - val_loss: 0.3337
# Epoch 4/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.8929 - loss: 0.2793 - val_accuracy: 0.8677 - val_loss: 0.3253
# Epoch 5/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9097 - loss: 0.2430 - val_accuracy: 0.8885 - val_loss: 0.2779
# Epoch 6/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9472 - loss: 0.1768 - val_accuracy: 0.8750 - val_loss: 0.3192
# Epoch 7/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.9675 - loss: 0.1267 - val_accuracy: 0.8802 - val_loss: 0.2766
# Epoch 8/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9645 - loss: 0.1152 - val_accuracy: 0.8771 - val_loss: 0.3164
# Epoch 9/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9695 - loss: 0.1027 - val_accuracy: 0.8667 - val_loss: 0.3361
# Epoch 10/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9812 - loss: 0.0812 - val_accuracy: 0.8906 - val_loss: 0.2775
# Epoch 11/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9821 - loss: 0.0728 - val_accuracy: 0.8958 - val_loss: 0.2751
# Epoch 12/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9947 - loss: 0.0420 - val_accuracy: 0.8990 - val_loss: 0.2540
# Epoch 13/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9996 - loss: 0.0286 - val_accuracy: 0.8969 - val_loss: 0.2937
# Epoch 14/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9963 - loss: 0.0306 - val_accuracy: 0.9073 - val_loss: 0.2594
# Epoch 15/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9993 - loss: 0.0179 - val_accuracy: 0.9052 - val_loss: 0.2488
# Epoch 16/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9998 - loss: 0.0120 - val_accuracy: 0.8958 - val_loss: 0.2608
# Epoch 17/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 1.0000 - loss: 0.0094 - val_accuracy: 0.9156 - val_loss: 0.2564
# Epoch 18/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.9135 - val_loss: 0.2566
# Epoch 19/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.9052 - val_loss: 0.2583
# Epoch 20/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.9083 - val_loss: 0.2670
# Epoch 21/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.9115 - val_loss: 0.2694
# Epoch 22/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9167 - val_loss: 0.2705
# Epoch 23/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.9115 - val_loss: 0.2786
# Epoch 24/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.9083 - val_loss: 0.2781
# Epoch 25/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9094 - val_loss: 0.2846
# Epoch 26/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9115 - val_loss: 0.2827
# Epoch 27/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9073 - val_loss: 0.2878
# Epoch 28/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9083 - val_loss: 0.2836
# Epoch 29/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9042 - val_loss: 0.2916
# Epoch 30/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9073 - val_loss: 0.3006
# Epoch 31/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9073 - val_loss: 0.2980
# Epoch 32/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.9062 - val_loss: 0.3002
# Epoch 33/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 1.0000 - loss: 9.6599e-04 - val_accuracy: 0.9042 - val_loss: 0.3122
# Epoch 34/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 1.0000 - loss: 9.2585e-04 - val_accuracy: 0.9094 - val_loss: 0.3140
# Epoch 35/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 1.0000 - loss: 8.0745e-04 - val_accuracy: 0.9062 - val_loss: 0.3140
# Epoch 36/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 1.0000 - loss: 7.0068e-04 - val_accuracy: 0.9135 - val_loss: 0.3088
# Epoch 37/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 1.0000 - loss: 6.0960e-04 - val_accuracy: 0.9052 - val_loss: 0.3192
# Epoch 38/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 1.0000 - loss: 5.1977e-04 - val_accuracy: 0.9062 - val_loss: 0.3176
# Epoch 39/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 1.0000 - loss: 5.3971e-04 - val_accuracy: 0.9104 - val_loss: 0.3213
# Epoch 40/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - accuracy: 1.0000 - loss: 4.5485e-04 - val_accuracy: 0.9125 - val_loss: 0.3250
# Epoch 41/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 1.0000 - loss: 4.0876e-04 - val_accuracy: 0.9031 - val_loss: 0.3280
# Epoch 42/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 1.0000 - loss: 3.6281e-04 - val_accuracy: 0.9052 - val_loss: 0.3328
# Epoch 43/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 1.0000 - loss: 3.7216e-04 - val_accuracy: 0.9073 - val_loss: 0.3279
# Epoch 44/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 1.0000 - loss: 3.0886e-04 - val_accuracy: 0.9104 - val_loss: 0.3421
# Epoch 45/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 1.0000 - loss: 2.7952e-04 - val_accuracy: 0.9052 - val_loss: 0.3396
# Epoch 46/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 1.0000 - loss: 2.6214e-04 - val_accuracy: 0.9062 - val_loss: 0.3370
# Epoch 47/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 1.0000 - loss: 2.4201e-04 - val_accuracy: 0.8990 - val_loss: 0.3459
# Epoch 48/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 1.0000 - loss: 2.3193e-04 - val_accuracy: 0.9083 - val_loss: 0.3411
# Epoch 49/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 1.0000 - loss: 1.9792e-04 - val_accuracy: 0.9031 - val_loss: 0.3452
# Epoch 50/50
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 1.0000 - loss: 1.9405e-04 - val_accuracy: 0.9000 - val_loss: 0.3493

# %%
val_acc_per_epoch = history.history['val_accuracy']
best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# Best epoch: 22

# %%
hypermodel = tuner.hypermodel.build(best_hps)

# Retrain the model
hypermodel.fit(x_train, y_train, epochs=best_epoch, validation_split=0.2)
# Out:
# Epoch 1/22
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 8s 45ms/step - accuracy: 0.2407 - loss: 1.9589 - val_accuracy: 0.6625 - val_loss: 1.0135
# Epoch 2/22
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.7451 - loss: 0.7549 - val_accuracy: 0.8146 - val_loss: 0.4874
# Epoch 3/22
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.8522 - loss: 0.4299 - val_accuracy: 0.8406 - val_loss: 0.3897
# Epoch 4/22
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.8974 - loss: 0.3057 - val_accuracy: 0.8531 - val_loss: 0.3705
# Epoch 5/22
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9056 - loss: 0.2603 - val_accuracy: 0.8490 - val_loss: 0.3699
# Epoch 6/22
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9307 - loss: 0.2057 - val_accuracy: 0.8708 - val_loss: 0.3300
# Epoch 7/22
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9469 - loss: 0.1654 - val_accuracy: 0.8635 - val_loss: 0.3289
# Epoch 8/22
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9522 - loss: 0.1446 - val_accuracy: 0.8719 - val_loss: 0.3208
# Epoch 9/22
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9676 - loss: 0.1053 - val_accuracy: 0.8990 - val_loss: 0.2496
# Epoch 10/22
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9865 - loss: 0.0751 - val_accuracy: 0.9000 - val_loss: 0.2449
# Epoch 11/22
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9920 - loss: 0.0491 - val_accuracy: 0.8875 - val_loss: 0.2629
# Epoch 12/22
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9903 - loss: 0.0552 - val_accuracy: 0.8990 - val_loss: 0.2553
# Epoch 13/22
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9973 - loss: 0.0322 - val_accuracy: 0.8927 - val_loss: 0.2776
# Epoch 14/22
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9963 - loss: 0.0292 - val_accuracy: 0.8990 - val_loss: 0.2656
# Epoch 15/22
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9982 - loss: 0.0218 - val_accuracy: 0.9010 - val_loss: 0.2645
# Epoch 16/22
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9999 - loss: 0.0147 - val_accuracy: 0.9021 - val_loss: 0.2512
# Epoch 17/22
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.9998 - loss: 0.0106 - val_accuracy: 0.9010 - val_loss: 0.2677
# Epoch 18/22
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 1.0000 - loss: 0.0098 - val_accuracy: 0.8938 - val_loss: 0.2848
# Epoch 19/22
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.9998 - loss: 0.0097 - val_accuracy: 0.8958 - val_loss: 0.2734
# Epoch 20/22
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.9010 - val_loss: 0.2777
# Epoch 21/22
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 0.9010 - val_loss: 0.2685
# Epoch 22/22
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.9010 - val_loss: 0.2700

# %%
eval_result = hypermodel.evaluate(x_test, y_test)
print("[test loss, test accuracy]:", eval_result)
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.9052 - loss: 0.2418
# [test loss, test accuracy]: [0.24994048476219177, 0.9058333039283752]

# %%
import matplotlib.pyplot as plt

# Plot Accuracy
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# Plot Loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
predictions=np.argmax(hypermodel.predict(x_test),axis=-1)
predicted_class=predictions[0]
print("Predicted class index:", predicted_class)
# Out:
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Predicted class index: 1

# %%
print("Predicted index:", predicted_class)
print("Predicted blood group:", blood_group[predicted_class])
# Out:
# Predicted index: 1
# Predicted blood group: A-

# %%
accuracy_score(y_test, predictions)
# Out:
# 0.9058333333333334

# %%
hypermodel.save('my_model.keras')

# %%
from keras.models import load_model

# %%
model=load_model('my_model.keras')

# %% [markdown]
# ### Prediction Space

# %%
def prediction_image(image_path):
  image=cv2.imread(image_path)
  image=cv2.resize(image,(128, 128))
  image=np.array(image, dtype='float') / 255.0
  image=np.expand_dims(image, axis=0)
  #print(image.shape)
  #print(image)
  return image

# %%
image_data_1="/content/cluster_7_2.BMP" # O- image

# %%
x=prediction_image(image_data_1)

# %%
predictions=np.argmax(model.predict(x), axis=-1)
predicted_class=predictions[0]
print("Predicted class index:", predicted_class)
print("Predicted blood group:", blood_group[predicted_class])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Predicted class index: 7
# Predicted blood group: O-

# %%
y_probs= model.predict(x)

predicted_class=np.argmax(y_probs[0])
print("Predicted class index:", predicted_class)
print("Predicted blood group:", blood_group[predicted_class])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Predicted class index: 7
# Predicted blood group: O-

# %%
import matplotlib.pyplot as plt

plt.bar(blood_group, y_probs[0])
plt.title("Prediction Confidence")
plt.ylabel("Probability")
plt.show()

# %%
def model_prediction(image_path):
  image=prediction_image(image_path)
  y_probs=model.predict(image)
  predicted_class=np.argmax(y_probs[0])
  print("Predicted class index:", predicted_class)
  print("Predicted blood group:", blood_group[predicted_class])

  plt.bar(blood_group, y_probs[0])
  plt.title("Prediction Confidence")
  plt.ylabel("Probability")
  plt.show()

# %%
image2="/content/cluster_7_2.BMP" # O-

# %%
model_prediction(image2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Predicted class index: 7
# Predicted blood group: O-

# %%
image3="/content/cluster_6_29.BMP" # O+

# %%
model_prediction(image3)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Predicted class index: 6
# Predicted blood group: O+

# %%
image4="/content/cluster_1_1.BMP" # A-

# %%
model_prediction(image4)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# Predicted class index: 1
# Predicted blood group: A-
